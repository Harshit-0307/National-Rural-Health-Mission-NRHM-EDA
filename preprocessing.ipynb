# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:\\Study\\Project\\National-Rural-Health-Mission-NRHM-EDA\\Datasets\\NRHM_dataset_merged.csv')
df.head()
# Out:
#                    States/UT  Required - [R]  Sanctioned - [S]  \
# 0  Andaman & Nicobar Islands              22              42.0
# 1             Andhra Pradesh            1147            1952.0
# 2          Arunachal Pradesh             143               NaN
# 3                      Assam            1014               NaN
# 4                      Bihar            1899            2078.0
#
#    In Position - [P]  Vacant - [S-P]  Shortfall - [R-P] Note of State/ UT  \
# 0                 34             8.0                NaN               NaN
# 1               1644           308.0                NaN               NaN
# 2                122             NaN               21.0               NaN
# 3               1048             NaN                NaN               NaN
# 4               1786           292.0              113.0                 #
#
#   Note of Vacant - [S-P] Note of Shortfall - [R-P]  \
# 0                    NaN                         *
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 90 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   States/UT                                         35 non-null     object
#  1   Required - [R]                                    35 non-null     int64
#  2   Sanctioned - [S]                                  32 non-null     float64
#  3   In Position - [P]                                 35 non-null     int64
#  4   Vacant - [S-P]                                    26 non-null     float64
#  5   Shortfall - [R-P]                                 14 non-null     float64
#  6   Note of State/ UT                                 3 non-null      object
#  7   Note of Vacant - [S-P]                            6 non-null      object
#  8   Note of Shortfall - [R-P]                         21 non-null     object
# ...

# %%
df.describe()
# Out:
#        Required - [R]  Sanctioned - [S]  In Position - [P]  Vacant - [S-P]  \
# count       35.000000         32.000000          35.000000       26.000000
# mean      1465.257143       1389.906250        1548.571429      431.884615
# std       4288.484933       2007.333625        4527.216398      683.463317
# min          4.000000          0.000000           7.000000        0.000000
# 25%         89.000000        123.000000         117.000000       84.000000
# 50%        538.000000        742.500000         492.000000      248.000000
# 75%       1225.500000       1816.250000        1199.000000      430.750000
# max      25642.000000      10530.000000       27100.000000     2943.000000
#
#        Shortfall - [R-P]  Total Number of SNCU (up to January, 2020)  \
# count          14.000000                                   35.000000
# mean          432.428571                                   49.314286
# std           831.670304                                  143.509330
# ...

# %%
nulls = df.isnull().sum()
print(nulls)
# Out:
# States/UT              0
# Required - [R]         0
# Sanctioned - [S]       3
# In Position - [P]      0
# Vacant - [S-P]         9
#                       ..
# Urban_Area             1
# Total_Area             0
# Rural_%                1
# Number_of_Districts    0
# Number_of_Villages     0
# Length: 90, dtype: int64

# %%
nulls_percentage = nulls[nulls!=0]/df.shape[0]*100
print('The percentage of null values per feature:\n')
print(round(nulls_percentage))
# Out:
# The percentage of null values per feature:
#
# Sanctioned - [S]              9.0
# Vacant - [S-P]               26.0
# Shortfall - [R-P]            60.0
# Note of State/ UT            91.0
# Note of Vacant - [S-P]       83.0
# Note of Shortfall - [R-P]    40.0
# ANM_Vacent                    9.0
# ANM_Shortfall                 3.0
# Doctors_Vacent                9.0
# Doctors_Shortfall             3.0
# Specialists_Vacent           11.0
# Specialists_Shortfall         3.0
# Radiographers_Vacent          9.0
# Radiographers_Shortfall       3.0
# Pharmacists_Vacent            9.0
# Pharmacists_Shortfall         3.0
# LabTechnicians_Vacent         9.0
# LabTechnicians_Shortfall      3.0
# NursingStaff_Vacent           9.0
# Nursing_Shortfall             3.0
# Rural_Population_Density      3.0
# Urban_Population_Density      3.0
# Tribal_Area                  31.0
# Rural_Area                    3.0
# Urban_Area                    3.0
# Rural_%                       3.0
# dtype: float64

# %%
# Dropped all the columns which are empty or have no data
df = df.drop(['Note of State/ UT', 'Note of Vacant - [S-P]', 'Note of Shortfall - [R-P]'], axis = 1)

# %%
df.head()
# Out:
#                    States/UT  Required - [R]  Sanctioned - [S]  \
# 0  Andaman & Nicobar Islands              22              42.0
# 1             Andhra Pradesh            1147            1952.0
# 2          Arunachal Pradesh             143               NaN
# 3                      Assam            1014               NaN
# 4                      Bihar            1899            2078.0
#
#    In Position - [P]  Vacant - [S-P]  Shortfall - [R-P]  \
# 0                 34             8.0                NaN
# 1               1644           308.0                NaN
# 2                122             NaN               21.0
# 3               1048             NaN                NaN
# 4               1786           292.0              113.0
#
#    Total Number of SNCU (up to January, 2020)  \
# 0                                           1
# 1                                          47
# 2                                           5
# 3                                          28
# ...

# %%
df.select_dtypes(include='number').nunique()
# Out:
# Required - [R]         33
# Sanctioned - [S]       32
# In Position - [P]      32
# Vacant - [S-P]         26
# Shortfall - [R-P]      13
#                        ..
# Urban_Area             34
# Total_Area             35
# Rural_%                34
# Number_of_Districts    25
# Number_of_Villages     35
# Length: 72, dtype: int64
